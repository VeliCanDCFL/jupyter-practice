# %% [markdown]
# # 📚 Lesson 4 — Merging DataFrames & Statistics
#
# **Time:** ~2 hours
# **Goal:** Learn to combine datasets and compute statistics.
#
# ---
#
# ## 🧠 Concept: Combining and Analyzing Data
#
# In real work, your data is often split across multiple tables. You need to:
# 1. **Merge** tables together (like SQL JOIN)
# 2. **Concatenate** tables (stack them)
# 3. **Compute statistics** to understand your data
#
# ---
#
# ## 📖 Part 1: Merging — `pd.merge()`
#
# Merging is like a VLOOKUP in Excel or JOIN in SQL. You combine two DataFrames based on a common column.
#
# ### The Four Join Types
#
# Imagine two tables:
#
# ```
# Table A (Customers)          Table B (Orders)
# ┌────┬─────────┐             ┌────┬──────────┐
# | ID | Name    |             | ID | Product  |
# ,
# 1
# 2
# ,
# 2
# 3
# ,
# 4
# 5
# ,
# ,
# ,
# ,
# ,
# ,
# ,
# ,
# ,
# ,
# ,
# ,
# ,
# ,
# ,
# ,
# ,
# ,
# ,
# ,
# ,
# ,
# ,
# ,
# ,
# ,
# ,
# 2
